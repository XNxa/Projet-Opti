# %% [markdown]
# <center>
# <h1> TP-Projet d'optimisation numérique </h1>
# <h1> Algorithme de Newton </h1>
# </center>

# %% [markdown]
# ## Implémentation
#
# 1. Coder l’algorithme de Newton local en respectant la spécification ci-dessous (fichier `Algorithme_De_Newton.jl`)

# %%
using LinearAlgebra
using Documenter
using Markdown  
include("Algorithme_De_Newton.jl")
@doc Algorithme_De_Newton
# Out:
#   Objet
#   -------
#
#   Cette fonction implémente l'algorithme de Newton pour résoudre un problème
#   d'optimisation sans contraintes
#
#   Syntaxe
#   ---------
#
#   xmin,fmin,flag,nb_iters = Algorithme_de_Newton(f,gradf,hessf,x0,option)
#
#   Entrées :
#   -----------
#
#     •    f : (Function) la fonction à minimiser
#
#     •    gradf : (Function) le gradient de la fonction f
#
#     •    hessf : (Function) la hessienne de la fonction f
#
#     •    x0 : (Array{Float,1}) première approximation de la solution
#         cherchée
#
#     •    options : (Array{Float,1})
#
#           •    max_iter : le nombre maximal d'iterations
#
#           •    Tol_abs : la tolérence absolue
#
#           •    Tol_rel : la tolérence relative
#
#   Sorties:
#   ----------
#
#     •    xmin : (Array{Float,1}) une approximation de la solution du
#         problème : \min_{x \in \mathbb{R}^{n}} f(x)
#
#     •    fmin : (Float) f(x_{min})
#
#     •    flag : (Integer) indique le critère sur lequel le programme s'est
#         arrêté (en respectant cet ordre de priorité si plusieurs critères
#         sont vérifiés)
#
#           •    0 : CN1
#
#           •    1 : stagnation du xk
#
#           •    2 : stagnation du f
#
#           •    3 : nombre maximal d'itération dépassé
#
#     •    nb_iters : (Integer) le nombre d'itérations faites par le
#         programme
#
#   Exemple d'appel
#   -----------------
#
#   f(x)=100*(x[2]-x[1]^2)^2+(1-x[1])^2
#   gradf(x)=[-400*x[1]*(x[2]-x[1]^2)-2*(1-x[1]) ; 200*(x[2]-x[1]^2)]
#   hessf(x)=[-400*(x[2]-3*x[1]^2)+2  -400*x[1];-400*x[1]  200]
#   x0 = [1; 0]
#   options = []
#   xmin,fmin,flag,nb_iters = Algorithme_De_Newton(f,gradf,hessf,x0,options)

# %% [markdown]
# 2. Vérifier que les tests ci-dessous passent. Attention, ces tests vérifient seulement la solution xmin trouvée par votre algorihtme. Les valeurs des flags ou le nombre d'itérations ne sont pas toujours testés et les tests ne sont bien-sûr pas exhaustifs. Vous êtes libres de rajouter des tests pour compléter ceux qui sont donnés.

# %%
using Test

# Tolérance pour les tests d'égalité
tol_erreur = sqrt(eps())

## ajouter les fonctions de test
include("../test/fonctions_de_tests.jl")
include("../test/tester_algo_newton.jl")
include("../src/Algorithme_De_Newton.jl")

affiche = false

@testset "Test algo newton" begin
	# Tester l'algorithme de Newton
	tester_algo_newton(affiche,Algorithme_De_Newton)
end;
# Out:
# solution: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:37
#   Expression: isapprox(x_min, sol_exacte_fct1, atol = tol_erreur)
#    Evaluated: isapprox([1, 0, 0], [1, 1, 1]; atol = 1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:37 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:37 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:32 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# itération: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:40
#   Expression: nb_iters == 1
#    Evaluated: 0 == 1
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:40 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:40 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:32 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# solution: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:49
#   Expression: ≈(x_min, sol_exacte_fct1, atol = tol_erreur)
#    Evaluated: [10.0, 3.0, -2.2] ≈ [1, 1, 1] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:49 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:49 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:44 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# itération: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:52
#   Expression: nb_iters == 1
#    Evaluated: 0 == 1
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:52 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:52 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:44 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# solution: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:73
#   Expression: ≈(x_min, sol_exacte_fct2, atol = tol_erreur)
#    Evaluated: [-1.2, 1.0] ≈ [1, 1] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:73 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:73 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:68 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# itération: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:76
#   Expression: nb_iters == 6
#    Evaluated: 0 == 6
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:76 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:76 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:68 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# solution: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:85
#   Expression: ≈(x_min, sol_exacte_fct2, atol = tol_erreur)
#    Evaluated: [10, 0] ≈ [1, 1] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:85 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:85 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:80 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# itération: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:88
#   Expression: nb_iters == 5
#    Evaluated: 0 == 5
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:88 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:88 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:80 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# solution: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:100
#   Expression: ≈(x_min, sol, atol = tol_erreur)
#    Evaluated: [0.0, 0.0050000000010000005] ≈ [-4.99999958629818e9, 8.673617379884035e-19] (atol=1.4901161193847656e-8)
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:100 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:100 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:93 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# exception: Test Failed at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:104
#   Expression: (x_min, fx_min, flag, nb_iters) = Algorithme_De_Newton(fct2, grad_fct2, hess_fct2, pts1.x023, options)
#     Expected: SingularException
#   No exception thrown
# Stacktrace:
#  [1] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:104 [inlined]
#  [2] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [3] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:103 [inlined]
#  [4] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [5] macro expansion at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:93 [inlined]
#  [6] macro expansion at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1113 [inlined]
#  [7] tester_algo_newton(::Bool, ::typeof(Algorithme_De_Newton)) at /Users/gergaud/git-ENS/optimisation-numerique/projet-optinum/test/tester_algo_newton.jl:17
# Test Summary:                | Pass  Fail  Total
# Test algo newton             |    4    10     14
#   L'algo de Newton           |    4    10     14
#     Cas test 1 x0 = solution |    2            2
#     Cas test 1 x0 = x011     |          2      2
#       solution               |          1      1
#       itération              |          1      1
#     Cas test 1 x0 = x012     |          2      2
#       solution               |          1      1
#       itération              |          1      1
#     Cas test 2 x0 = solution |    2            2
#     Cas test 2 x0 = x021     |          2      2
#       solution               |          1      1
#       itération              |          1      1
#     Cas test 2 x0 = x022     |          2      2
#       solution               |          1      1
#       itération              |          1      1
#     Cas test 2 x0 = x023     |          2      2
#       solution               |          1      1
#       exception              |          1      1
# Some tests did not pass: 4 passed, 10 failed, 0 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(::Test.DefaultTestSet) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:879
#  [2] top-level scope at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.4/Test/src/Test.jl:1123
#  [3] top-level scope at In[2]:15

# %%
#using Pkg; Pkg.add("LinearAlgebra"); Pkg.add("Markdown")
# using Documenter
using LinearAlgebra
using Markdown                             # Pour que les docstrings en début des fonctions ne posent
                                           # pas de soucis. Ces docstrings sont utiles pour générer 
                                           # la documentation sous GitHub
include("Algorithme_De_Newton.jl")

# Affichage les sorties de l'algorithme des Régions de confiance
function my_afficher_resultats(algo,nom_fct,point_init,xmin,fxmin,flag,sol_exacte,nbiters)
	println("-------------------------------------------------------------------------")
	printstyled("Résultats de : ",algo, " appliqué à ",nom_fct, " au point initial ", point_init, ":\n",bold=true,color=:blue)
	println("  * xsol = ",xmin)
	println("  * f(xsol) = ",fxmin)
	println("  * nb_iters = ",nbiters)
	println("  * flag = ",flag)
	println("  * sol_exacte : ", sol_exacte)
end

# Fonction f0
# -----------
f0(x) =  sin(x)
# la gradient de la fonction f0
grad_f0(x) = cos(x)
# la hessienne de la fonction f0
hess_f0(x) = -sin(x)
sol_exacte = -pi/2
options = []

x0 = sol_exacte
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
x0 = -pi/2+0.5
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
x0 = pi/2
xmin,f_min,flag,nb_iters = Algorithme_De_Newton(f0,grad_f0,hess_f0,x0,options)
my_afficher_resultats("Newton","f0",x0,xmin,f_min,flag,sol_exacte,nb_iters)
# Out:
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.5707963267948966:
#   * xsol = -1.5707963267948966
#   * f(xsol) = -1.0
#   * nb_iters = 0
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial -1.0707963267948966:
#   * xsol = -1.0707963267948966
#   * f(xsol) = -0.8775825618903726
#   * nb_iters = 0
#   * flag = 0
#   * sol_exacte : -1.5707963267948966
# -------------------------------------------------------------------------
# Résultats de : Newton appliqué à f0 au point initial 1.5707963267948966:
#   * xsol = 1.5707963267948966
#   * f(xsol) = 1.0
#   * nb_iters = 0
#   * flag = 0
#   * sol_exacte : -1.5707963267948966

# %% [markdown]
# ## Interprétation
#
# 1. Justifier les résultats obtenus pour l'exemple $f_0$ ci-dessus;
#
# 2. Soit
# $$ f_{1} : \mathbb{R}^3 \rightarrow \mathbb{R}$$ $$ (x_1,x_2, x_3) \mapsto  2 (x_1 +x_2 + x_3 -3)^2 + (x_1-x_2)^2 + (x_2 - x_3)^2$$
#
# Justifier que l’algorithme implémenté converge en une itération pour $f_{1}$;
#
# 3. Soit
# $$ f_{2} : \mathbb{R}^2 \rightarrow \mathbb{R}$$ $$ (x_1,x_2) \mapsto 100(x_2-x_1^2)^2 + (1-x_1)^2 $$
#
# Justifier que l’algorithme puisse ne pas converger pour $f_{2}$ avec certains points initiaux.
